# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn

# %%
class DataProcessor:
    def __init__(self):
        pass

    def read_file(self, file_path):
        file_type = file_path[-4:]

        if file_type == '.csv':
            return pd.read_csv(file_path)
        elif file_type in ['.xlsx', '.xls']:
            return pd.read_excel(file_path)
        elif file_type == '.json':
            return pd.read_json(file_path)
        else:
            raise ValueError(f"Oops, unsupported file type: {file_type}\nOnly supported file types at the moment are:\n1- .csv\n2- .xlsc\n3- .xls\n4- .json")

    def data_summary(self, df):
        stats = []

        for col in df.columns:
            col_type = df[col].dtype

            if col_type in ['int64', 'float64']:
                mean = df[col].mean()
                median = df[col].median()
                mode = df[col].mode()[0]
                fst_qrt = df[col].quantile(0.25)
                third_qrt = df[col].quantile(0.75)
                min_val = df[col].min()
                max_val = df[col].max()
                duplicated = df[col].duplicated().sum()
                null_values = df[col].isnull().sum()
                cats = None
                cats_freq = None
            elif col_type == 'object':
                mean = None
                median = None
                mode = df[col].mode()[0]
                fst_qrt = None
                third_qrt = None
                min_val = None
                max_val = None
                duplicated = df[col].duplicated().sum()
                null_values = df[col].isnull().sum()
                cats = df[col].nunique()
                cats_freq = df[col].value_counts().to_dict()
            else:
                continue

            smry = pd.DataFrame({
                'column_name': [col],
                'column_type': [col_type],
                'mean': [mean],
                'median': [median],
                'mode': [mode],
                '1st_quartile': [fst_qrt],
                '3rd_quartile': [third_qrt],
                'min': [min_val],
                'max': [max_val],
                'duplicates': [duplicated],
                'null_values': [null_values],
                'categories': [cats],
                'categories_frequencies': [cats_freq]
            })

            stats.append(smry)

        smry = pd.concat(stats, ignore_index=True)

        return smry

    def handle_missing_values(self, df):
        if df.isnull().sum().sum() != 0:
            print("!!!THE DATASET CONTAINS SOME MISSING VALUES!!!")

            cols = df.columns[df.isnull().any()]

            print("Columns containing missing values:")
            print(cols)

            for col in cols:
                if df[col].isnull().mean() * 100 > 50:
                    df.drop(col, axis=1, inplace=True)
                    print(f"The '{col}' column was dropped because more than 50% of the column's values are missing")
                elif df[col].dtype in ['int64', 'float64']:
                    df[col].fillna(df[col].mean(), inplace=True)
                else:
                    mode_value = df[col].mode()[0]
                    df[col].fillna(mode_value, inplace=True)
                    print(f"The '{col}' column's missing values were filled with the mode of the column")

            if df.isnull().sum().sum() == 0:
                print("THE DATASET DOESN'T CONTAIN ANY MISSING VALUES ANYMORE!! :)")
        else:
            print("THE DATASET DOESN'T CONTAIN ANY MISSING VALUES!! :)")

        return df

    def encode_categorical(self, df):
        obj_cols = df.select_dtypes(include=['object']).columns
        encoded_df = pd.get_dummies(df, columns=obj_cols)
        return encoded_df

# %%
processor = DataProcessor()

df = processor.read_file('/content/drive/MyDrive/Complaints.csv')

df_summary = processor.data_summary(df)
print(df_summary)

cleaned_df = processor.handle_missing_values(df)
print(cleaned_df)

encoded_df = processor.encode_categorical(cleaned_df)
print(encoded_df)
# Out:
#                column_name column_type      mean median  \
# 0                  CASE_ID      object      None   None
# 1               OFFER_NAME      object      None   None
# 2            CUSTOMER_TYPE      object      None   None
# 3           CUSTOMER_GROUP      object      None   None
# 4           CURRENT_STATUS      object      None   None
# 5          ESCALATION_FLAG      object      None   None
# 6          ESCALATED_GROUP      object      None   None
# 7                OPEN_DATE      object      None   None
# 8                OPEN_USER      object      None   None
# 9               CLOSE_DATE      object      None   None
# 10             CLOSE_GROUP      object      None   None
# 11              CLOSE_USER      object      None   None
# 12             AGE_BRACKET     float64  1.503302    1.0
# 13        ACTUAL_COMPLAINT      object      None   None
# 14      CALLBACK_MECHANISM      object      None   None
# 15              RESOLUTION      object      None   None
# 16  RESOLUTION_DESCRIPTION      object      None   None
# 17               CASE_DESC      object      None   None
# 18                 OPEN_GR      object      None   None
# 19          COMPLAINT_TYPE      object      None   None
# 20                 PRODUCT      object      None   None
# 21                    CASE      object      None   None
#
#                      mode 1st_quartile 3rd_quartile   min    max  duplicates  \
# 0      CAS-1007107-D9L6M4         None         None  None   None          36
# 1               FTTH Home         None         None  None   None       10274
# 2                     CBU         None         None  None   None       10413
# 3               FTTH Home         None         None  None   None       10341
# 4                Resolved         None         None  None   None       10413
# 5                      No         None         None  None   None       10413
# 6               Mobile_BO         None         None  None   None       10390
# 7        01.05.2022 12:58         None         None  None   None         370
# 8             TCRMService         None         None  None   None       10143
# 9         7/17/2022 11:31         None         None  None   None         579
# 10    CYC_COMMERCAIL_TEAM         None         None  None   None       10368
# 11               MOHAMMAD         None         None  None   None       10125
# 12                    1.0          1.0          1.0   1.0  116.0       10376
# 13        User Not Filled         None         None  None   None       10412
# 14                    SMS         None         None  None   None       10410
# 15                   Done         None         None  None   None       10413
# 16                   Done         None         None  None   None       10412
# 17                   Done         None         None  None   None       10412
# 18  CBU - CC 1st Layer A          None         None  None   None       10396
# 19              Technical         None         None  None   None       10413
# 20               Internet         None         None  None   None       10413
# 21    Technical complaint         None         None  None   None       10410
#
#     null_values categories                             categories_frequencies
# 0             0      10379  {'CAS-1580304-T7T3B9': 2, 'CAS-1051157-N8W4F0'...
# 1          1293        140  {'FTTH Home': 3914, 'Bitstream Home': 2787, 'O...
# 2             0          2                         {'CBU': 10190, 'EBU': 225}
# 3          1348         73  {'FTTH Home': 3648, 'Wanadoo-ADSL-Res': 2465, ...
# 4             0          2                 {'Resolved': 10292, 'Active': 123}
# 5             0          2                          {'No': 7020, 'Yes': 3395}
# 6          7055         24  {'Mobile_BO': 1481, 'F&I_BO': 934, 'CENTRALIZE...
# 7             0      10045  {'17.04.2022 11:38': 3, '18.06.2022 12:29': 3,...
# 8           362        271  {'TCRMService': 1214, 'AHMAD': 428, 'MOHAMMAD'...
# 9           119       9835  {'7/17/2022 11:31': 8, '01.05.2022 10:45': 7, ...
# 10         4890         46  {'CYC_COMMERCAIL_TEAM': 1379, 'F&I_BO': 687, '...
# 11          516        289  {'MOHAMMAD': 457, 'AHMAD': 373, 'ENNAS': 358, ...
# 12          119       None                                               None
# 13            0          3  {'User Not Filled': 7277, 'Actual Complaint': ...
# 14         7277          4  {'SMS': 1419, 'Phone': 1361, 'E-mail': 345, 'A...
# 15        10336          1                                       {'Done': 79}
# 16        10376          2                              {'Done': 38, 'OK': 1}
# 17         9243          2                            {'Done': 1167, 'OK': 5}
# 18         4561         18  {'CBU - CC 1st Layer A ': 2913, 'System Admini...
# 19            0          2            {'Technical': 7952, 'Commercial': 2463}
# 20            0          2                 {'Internet': 7297, 'Mobile': 3118}
# 21            0          5  {'Technical complaint': 7654, 'Commercial clai...
# !!!THE DATASET CONTAINS SOME MISSING VALUES!!!
# Columns containing missing values:
# Index(['OFFER_NAME', 'CUSTOMER_GROUP', 'ESCALATED_GROUP', 'OPEN_USER',
#        'CLOSE_DATE', 'CLOSE_GROUP', 'CLOSE_USER', 'AGE_BRACKET',
#        'CALLBACK_MECHANISM', 'RESOLUTION', 'RESOLUTION_DESCRIPTION',
#        'CASE_DESC', 'OPEN_GR'],
#       dtype='object')
# The 'OFFER_NAME' column's missing values were filled with the mode of the column
# The 'CUSTOMER_GROUP' column's missing values were filled with the mode of the column
# The 'ESCALATED_GROUP' column was dropped because more than 50% of the column's values are missing
# The 'OPEN_USER' column's missing values were filled with the mode of the column
# The 'CLOSE_DATE' column's missing values were filled with the mode of the column
# The 'CLOSE_GROUP' column's missing values were filled with the mode of the column
# The 'CLOSE_USER' column's missing values were filled with the mode of the column
# The 'CALLBACK_MECHANISM' column was dropped because more than 50% of the column's values are missing
# The 'RESOLUTION' column was dropped because more than 50% of the column's values are missing
# The 'RESOLUTION_DESCRIPTION' column was dropped because more than 50% of the column's values are missing
# The 'CASE_DESC' column was dropped because more than 50% of the column's values are missing
# The 'OPEN_GR' column's missing values were filled with the mode of the column
# THE DATASET DOESN'T CONTAIN ANY MISSING VALUES ANYMORE!! :)
#                   CASE_ID      OFFER_NAME CUSTOMER_TYPE    CUSTOMER_GROUP  \
# 0      CAS-1060890-L3D6Q6       FTTH Home           CBU         FTTH Home
# 1       CAS-388567-W4B9Q3       FTTH Home           CBU         FTTH Home
# 2      CAS-1494939-L9F0X7  Bitstream Home           CBU  Wanadoo-ADSL-Res
# 3      CAS-1059985-K3Y9F7       FTTH Home           CBU         FTTH Home
# 4      CAS-1239942-Y1S2F5       FTTH Home           CBU         FTTH Home
# ...                   ...             ...           ...               ...
# 10410   CAS-549162-Y2F4X6  OnLine Prepaid           CBU           Prepaid
# 10411  CAS-1094578-B7J7Z0       FTTH Home           CBU         FTTH Home
# 10412   CAS-470088-Q3Y2V7  FTTB Corporate           EBU    FTTB Corporate
# 10413  CAS-1249800-V2H6C7  Bitstream Home           CBU  Wanadoo-ADSL-Res
# 10414   CAS-805076-V0F0N9  Bitstream Home           CBU  Wanadoo-ADSL-Res
#
#       CURRENT_STATUS ESCALATION_FLAG         OPEN_DATE    OPEN_USER  \
# 0           Resolved             Yes  19.06.2022 06:07         DANA
# 1           Resolved             Yes  04.04.2022 14:11  TCRMService
# 2           Resolved              No  03.08.2022 03:20       MOUTAZ
# 3           Resolved              No  18.06.2022 20:38        MOATH
# 4           Resolved              No  06.07.2022 01:22      IBRAHIM
# ...              ...             ...               ...          ...
# 10410       Resolved              No  23.04.2022 09:31        ABRAR
# 10411       Resolved              No  21.06.2022 19:40        AHMAD
# 10412       Resolved              No  14.04.2022 14:36      YASMEEN
# 10413       Resolved              No  07.07.2022 05:54      ALANOUD
# 10414       Resolved              No  22.05.2022 20:31      HUSSEIN
#
#              CLOSE_DATE          CLOSE_GROUP CLOSE_USER  AGE_BRACKET  \
# 0      21.06.2022 13:41               F&I_BO       DANA          2.0
# 1      05.04.2022 12:13            Mobile_BO      ENNAS          1.0
# 2      03.08.2022 03:20  CYC_COMMERCAIL_TEAM     MOUTAZ          1.0
# 3      18.06.2022 20:38  CYC_COMMERCAIL_TEAM      MOATH          1.0
# 4      06.07.2022 01:22  CYC_COMMERCAIL_TEAM    IBRAHIM          1.0
# ...                 ...                  ...        ...          ...
# 10410  23.04.2022 09:31  CYC_COMMERCAIL_TEAM      ABRAR          1.0
# 10411  21.06.2022 19:40  CYC_COMMERCAIL_TEAM      AHMAD          1.0
# 10412  14.04.2022 14:36  CYC_COMMERCAIL_TEAM    YASMEEN          1.0
# 10413  07.07.2022 05:54  CYC_COMMERCAIL_TEAM    ALANOUD          1.0
# 10414  22.05.2022 20:31  CYC_COMMERCAIL_TEAM    HUSSEIN          1.0
#
#            ACTUAL_COMPLAINT                    OPEN_GR COMPLAINT_TYPE  \
# 0          Actual Complaint  CBU / EBU - personal view      Technical
# 1      Not Actual Complaint       System Administrator     Commercial
# 2           User Not Filled      CBU - CC 1st Layer A       Technical
# 3           User Not Filled      CBU - CC 1st Layer A       Technical
# 4           User Not Filled      CBU - CC 1st Layer A       Technical
# ...                     ...                        ...            ...
# 10410       User Not Filled      CBU - CC 1st Layer A      Commercial
# 10411       User Not Filled      CBU - CC 1st Layer A       Technical
# 10412       User Not Filled      CBU - CC 1st Layer A       Technical
# 10413       User Not Filled      CBU - CC 1st Layer A       Technical
# 10414       User Not Filled      CBU - CC 1st Layer A       Technical
#
#         PRODUCT                 CASE
# 0      Internet  Technical complaint
# 1        Mobile     Commercial claim
# 2      Internet  Technical complaint
# 3      Internet  Technical complaint
# 4      Internet  Technical complaint
# ...         ...                  ...
# 10410    Mobile     Commercial claim
# 10411  Internet  Technical complaint
# 10412  Internet  Technical complaint
# 10413  Internet  Technical complaint
# 10414  Internet  Technical complaint
#
# [10415 rows x 17 columns]
#        AGE_BRACKET  CASE_ID_CAS-1000062-L5W2C4  CASE_ID_CAS-1000298-V4K0X0  \
# 0              2.0                       False                       False
# 1              1.0                       False                       False
# 2              1.0                       False                       False
# 3              1.0                       False                       False
# 4              1.0                       False                       False
# ...            ...                         ...                         ...
# 10410          1.0                       False                       False
# 10411          1.0                       False                       False
# 10412          1.0                       False                       False
# 10413          1.0                       False                       False
# 10414          1.0                       False                       False
#
#        CASE_ID_CAS-1000393-N6R3Z7  CASE_ID_CAS-1000396-K6V0F0  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 10410                       False                       False
# 10411                       False                       False
# 10412                       False                       False
# 10413                       False                       False
# 10414                       False                       False
#
#        CASE_ID_CAS-1000429-C9W5G6  CASE_ID_CAS-1000440-D0P6M5  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 10410                       False                       False
# 10411                       False                       False
# 10412                       False                       False
# 10413                       False                       False
# 10414                       False                       False
#
#        CASE_ID_CAS-1000455-R6D9W8  CASE_ID_CAS-1000637-T3S8C8  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 10410                       False                       False
# 10411                       False                       False
# 10412                       False                       False
# 10413                       False                       False
# 10414                       False                       False
#
#        CASE_ID_CAS-1000732-Z1S2F7  ...  OPEN_GR_System Administrator  \
# 0                           False  ...                         False
# 1                           False  ...                          True
# 2                           False  ...                         False
# 3                           False  ...                         False
# 4                           False  ...                         False
# ...                           ...  ...                           ...
# 10410                       False  ...                         False
# 10411                       False  ...                         False
# 10412                       False  ...                         False
# 10413                       False  ...                         False
# 10414                       False  ...                         False
#
#        COMPLAINT_TYPE_Commercial  COMPLAINT_TYPE_Technical  PRODUCT_Internet  \
# 0                          False                      True              True
# 1                           True                     False             False
# 2                          False                      True              True
# 3                          False                      True              True
# 4                          False                      True              True
# ...                          ...                       ...               ...
# 10410                       True                     False             False
# 10411                      False                      True              True
# 10412                      False                      True              True
# 10413                      False                      True              True
# 10414                      False                      True              True
#
#        PRODUCT_Mobile  CASE_Commercial claim  CASE_OJO-Internal  \
# 0               False                  False              False
# 1                True                   True              False
# 2               False                  False              False
# 3               False                  False              False
# 4               False                  False              False
# ...               ...                    ...                ...
# 10410            True                   True              False
# 10411           False                  False              False
# 10412           False                  False              False
# 10413           False                  False              False
# 10414           False                  False              False
#
#        CASE_OM Technical  CASE_OM_CLAIM  CASE_Technical complaint
# 0                  False          False                      True
# 1                  False          False                     False
# 2                  False          False                      True
# 3                  False          False                      True
# 4                  False          False                      True
# ...                  ...            ...                       ...
# 10410              False          False                     False
# 10411              False          False                      True
# 10412              False          False                      True
# 10413              False          False                      True
# 10414              False          False                      True
#
# [10415 rows x 31115 columns]
